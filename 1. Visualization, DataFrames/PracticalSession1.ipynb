# %% [markdown]
# # Exercise 1

# %%
# linear algebra
import numpy as np 
# data processing
import pandas as pd

# %% [markdown]
# ## Question 1 : Import the data

# %%
df=pd.read_csv("titanic(1).csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ## Question 2 : describe the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ## Question 3 : basic statistics

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Total of missing values for each feature

# %%
total = df.isnull().sum().sort_values(ascending=False)
total
# Out:
# Cabin          687
# Age            177
# Embarked         2
# Fare             0
# Ticket           0
# Parch            0
# SibSp            0
# Sex              0
# Name             0
# Pclass           0
# Survived         0
# PassengerId      0
# dtype: int64

# %% [markdown]
#  ### Percentage of missing values for each feature

# %%
percent_1 = df.isnull().sum()/df.isnull().count()*100
percent_1
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# ### Sorted percentage of missing values for each feature

# %%
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
percent_2
# Out:
# Cabin          77.1
# Age            19.9
# Embarked        0.2
# Fare            0.0
# Ticket          0.0
# Parch           0.0
# SibSp           0.0
# Sex             0.0
# Name            0.0
# Pclass          0.0
# Survived        0.0
# PassengerId     0.0
# dtype: float64

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ### drop columns

# %%
colonnes=['PassengerId','Ticket','Name']
df.drop(colonnes, axis=1)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare        Cabin  \
# 0           0       3    male  22.0      1      0    7.2500          NaN
# 1           1       1  female  38.0      1      0   71.2833          C85
# 2           1       3  female  26.0      0      0    7.9250          NaN
# 3           1       1  female  35.0      1      0   53.1000         C123
# 4           0       3    male  35.0      0      0    8.0500          NaN
# 5           0       3    male   NaN      0      0    8.4583          NaN
# 6           0       1    male  54.0      0      0   51.8625          E46
# 7           0       3    male   2.0      3      1   21.0750          NaN
# 8           1       3  female  27.0      0      2   11.1333          NaN
# 9           1       2  female  14.0      1      0   30.0708          NaN
# 10          1       3  female   4.0      1      1   16.7000           G6
# 11          1       1  female  58.0      0      0   26.5500         C103
# ...

# %% [markdown]
# ## Basic Graphic Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### We separate the dataset into men and women

# %%
women = df[df['Sex']=='female']
men = df[df['Sex']=='male']

# %% [markdown]
# ### We separate the labels

# %%
survived = 'survived'
not_survived = 'not survived'

# %% [markdown]
# ### Plot the results: distribution of survivors for men and women

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
#Plot for women
ax = sns.distplot(women[women['Survived']==1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde =False)
ax = sns.distplot(women[women['Survived']==0].Age.dropna(), bins=40, label = not_survived, ax = axes[0], kde =False)
ax.legend()
ax.set_title('Female')
#Plot for men; dropna - return objects with labels omitted
ax = sns.distplot(men[men['Survived']==1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False)
ax = sns.distplot(men[men['Survived']==0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False)
ax.legend() 
ax.set_title('Male')
# Out:
# Text(0.5, 1.0, 'Male')

# %% [markdown]
# ### Plot a Facet Grid

# %%
# height - size in inches; Aspect ratio of each facet, so that aspect * height gives the width of each facet in inches.
FacetGrid = sns.FacetGrid(df, row='Embarked', height=4.5, aspect=1.6)

FacetGrid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette=None,  order=None, hue_order=None )
FacetGrid.add_legend()

# %% [markdown]
# ## Question 4

# %%
sns.barplot(x='Pclass', y='Survived', data=df)
